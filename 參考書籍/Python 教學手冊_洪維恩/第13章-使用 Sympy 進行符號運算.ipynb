# %% [markdown]
# <font color=#1E8449>☘ </font> 注意事項
# 1. 如果您使用 Colab，在您熟悉 Colab 的操作環境之後，建議把介面改成英文版，以便讓程式碼有最好的顯示效果
#  * 選擇 Colab 功能表裡的 <font color=#E59866>說明</font> - <font color=#E59866>查看英文版本</font> 即可將介面改成英文版
#  * 要改回中文版，請關掉目前開啟的 Colab 網頁，再重新開啟您執行的 Colab 檔案即可（Colab 預設為中文版）
# 2. 建議選擇暗色背景，長時間撰寫程式時眼睛會比較舒服
#  * 在 Colab 裡選擇 <font color=#E59866>Tools（工具）</font> - <font color=#E59866> Settings （設定）</font> - <font color=#E59866> Site（網站）</font> - <font color=#E59866> Theme （主題）</font> - <font color=#E59866> Dark </font>
#  * 在 Jupyter lab 中選擇 <font color=#E59866> Settings </font> - <font color=#E59866> JupyterLab theme </font> - <font color=#E59866> JupyerterLab Dark </font>

# %% [markdown]
# ## Chap 13 使用 Sympy 進行符號運算

# %%
import sympy as sp
import numpy as np

# %%
sp.init_printing()

# %% [markdown]
# ## 13.1 Sympy 套件與符號物件

# %% [markdown]
# ### 13.1.1 建立符號變數

# %%
x=sp.Symbol('x')

# %%
type(x)
# Out:
# sympy.core.symbol.Symbol

# %%
y=sp.Symbol('y')

# %%
2*x**2+x*y+y
# Out:
#    2
# 2⋅x  + x⋅y + y

# %%
x+3*y-(6*y-5*x)
# Out:
# 6⋅x - 3⋅y

# %%
x,y,z=sp.symbols('x,y,z')  # 注意 symbols 的 s 是小寫

# %%
ex=x**2+z**3-2*x*y*z

# %%
ex
# Out:
#  2              3
# x  - 2⋅x⋅y⋅z + z

# %%
ex.subs(x,2)
# Out:
#           3
# -4⋅y⋅z + z  + 4

# %%
ex.subs(x,2).subs(y,5)
# Out:
#  3
# z  - 20⋅z + 4

# %%
ex.subs({x:2,y:5})
# Out:
#  3
# z  - 20⋅z + 4

# %%
ex.subs([(x,2),(y,5),(z,0)])
# Out:
# 4

# %%
alp,eps,dlt=sp.symbols('alpha,epsilon,Delta')

# %%
alp**2+eps*dlt**2+dlt**4
# Out:
#  4    2      2
# Δ  + Δ ⋅ε + α

# %%
sp.symbols('a1')
# Out:
# a₁

# %%
sp.symbols('a:5')
# Out:
# (a₀, a₁, a₂, a₃, a₄)

# %%
b1,b2,b3=sp.symbols('b(1:4)')

# %%
b1**2+b2-b3/4
# Out:
#   2        b₃
# b₁  + b₂ - ──
#            4

# %%
u=sp.S(24); u
# Out:
# 24

# %%
2*u+4
# Out:
# 52

# %%
u/8, u/7
# Out:
# (3, 24/7)

# %%
type(u)
# Out:
# sympy.core.numbers.Integer

# %%
v=24

# %%
type(v)
# Out:
# int

# %%
v/7
# Out:
# 3.4285714285714284

# %%
(u/7).evalf()
# Out:
# 3.42857142857143

# %%
(u/7).evalf(20)
# Out:
# 3.4285714285714285714

# %%
sp.N(u/7,30)
# Out:
# 3.42857142857142857142857142857

# %%
11/14  # numerical result
# Out:
# 0.7857142857142857

# %%
sp.Rational(11,14)+1
# Out:
# 25
# ──
# 14

# %%
11/sp.S('14')
# Out:
# 11
# ──
# 14

# %%
sp.Rational(11,14)+sp.Rational(9,13)
# Out:
# 269
# ───
# 182

# %%
sp.Rational(11,14)+0.5
# Out:
# 1.28571428571429

# %%
r=sp.Rational(0.25)
r
# Out:
# 1/4

# %%
type(r)
# Out:
# sympy.core.numbers.Rational

# %%
r.p, r.q
# Out:
# (1, 4)

# %% [markdown]
# ### 13.1.2 常數物件

# %%
sp.pi**2+1
# Out:
#      2
# 1 + π

# %%
sp.exp(1)**sp.pi
# Out:
#  π
# ℯ

# %%
sp.E**2+6
# Out:
#      2
# 6 + ℯ

# %%
sp.oo+5
# Out:
# ∞

# %%
5+7*sp.I
# Out:
# 5 + 7⋅ⅈ

# %%
sp.E**(sp.I*sp.pi)+1
# Out:
# 0

# %%
z=sp.UnevaluatedExpr(sp.E)

# %%
ex=z**(sp.I*sp.pi)+1

# %%
ex
# Out:
#      ⅈ⋅π
# 1 + ℯ

# %%
ex.doit()
# Out:
# 0

# %%
ex=sp.E**(sp.I*sp.symbols('pi'))+1 
ex
# Out:
#  ⅈ⋅π
# ℯ    + 1

# %%
ex.subs(sp.symbols('pi'),sp.pi).doit()
# Out:
# 0

# %% [markdown]
# ### 13.1.3 變數的性質

# %%
alp=sp.symbols('alpha')

# %%
sp.sqrt(alp**2)
# Out:
#    ____
#   ╱  2
# ╲╱  α

# %%
sp.sqrt(sp.pi**2)
# Out:
# π

# %%
alp=sp.symbols('alpha',positive=True)

# %%
sp.sqrt(alp**2)
# Out:
# α

# %%
x=sp.Symbol('x',even=True)

# %%
x.is_integer
# Out:
# True

# %%
x.is_positive

# %%
y=x+0.3

# %%
y.is_integer
# Out:
# False

# %%
a=sp.Symbol('a',real=True)

# %%
sp.sqrt(a**2)
# Out:
# │a│

# %% [markdown]
# ### 13.1.4 將數學式轉成 Latex

# %%
ex=sp.E**2/(1+sp.pi)+3; ex
# Out:
#    2
#   ℯ
# ───── + 3
# 1 + π

# %%
print(sp.latex(ex))
# Out:
# \frac{e^{2}}{1 + \pi} + 3

# %% [markdown]
# <font color=#1EA004>☘ </font> 數學式： $\frac{e^{2}}{1 + \pi} + 3$

# %% [markdown]
# <font color=#1EA004>☘ </font> 方程式置中：$$\frac{e^{2}}{1 + \pi} + 3$$

# %% [markdown]
# ## 13.2 基本代數運算

# %%
a,b,x=sp.symbols('a,b,x')

# %% [markdown]
# ### 13.2.1 Sympy 提供的數學函數

# %%
a+sp.sin(a**2)+sp.cos(b)**2
# Out:
#        ⎛ 2⎞      2
# a + sin⎝a ⎠ + cos (b)

# %%
sp.Abs(a)+sp.sqrt(sp.tan(b))
# Out:
#   ________
# ╲╱ tan(b)  + │a│

# %%
abs(a**2+5)
# Out:
# │ 2    │
# │a  + 5│

# %%
d=sp.symbols('d',negative=True)

# %%
sp.Abs(d)
# Out:
# -d

# %%
sp.Max(d,sp.pi,sp.E)
# Out:
# π

# %%
sp.Min(sp.pi**sp.E,sp.E**sp.pi)
# Out:
#  ℯ
# π

# %%
sp.log(a,b)
# Out:
# log(a)
# ──────
# log(b)

# %%
sp.log(512,2)
# Out:
# 9

# %%
sp.root(24,3)
# Out:
#   3 ___
# 2⋅╲╱ 3

# %%
sp.factorial(x)
# Out:
# x!

# %% [markdown]
# ### 13.2.2 多項式與分式的運算

# %%
a,b,x=sp.symbols('a,b,x')

# %%
ex=sp.expand((a+b)**3)
ex
# Out:
#  3      2          2    3
# a  + 3⋅a ⋅b + 3⋅a⋅b  + b

# %%
sp.factor(ex)
# Out:
#        3
# (a + b)

# %%
ex=sp.expand(sp.sin(a+b),trig=True)
ex
# Out:
# sin(a)⋅cos(b) + sin(b)⋅cos(a)

# %%
sp.factor(ex)
# Out:
# sin(a)⋅cos(b) + sin(b)⋅cos(a)

# %%
sp.simplify(ex)
# Out:
# sin(a + b)

# %%
sp.expand(sp.sin(2*a),trig=True)
# Out:
# 2⋅sin(a)⋅cos(a)

# %%
sp.factor(a**3-2*a**2-3*a)
# Out:
# a⋅(a - 3)⋅(a + 1)

# %%
sp.simplify(sp.sin(2*x)*sp.cos(2*x))
# Out:
# sin(4⋅x)
# ────────
#    2

# %%
sp.trigsimp(2*sp.sin(x)*sp.cos(x))
# Out:
# sin(2⋅x)

# %%
sp.collect(x**2+x*a**2+a*x+3,x)
# Out:
#  2     ⎛ 2    ⎞
# x  + x⋅⎝a  + a⎠ + 3

# %%
sp.collect(x**2+x*a**2+a*x+3,a)
# Out:
#  2            2
# a ⋅x + a⋅x + x  + 3

# %%
ex=(a-2)/(a**3+6*a**2-a-30)
ex
# Out:
#       a - 2
# ──────────────────
#  3      2
# a  + 6⋅a  - a - 30

# %%
sp.cancel(ex)
# Out:
#       1
# ─────────────
#  2
# a  + 8⋅a + 15

# %%
sp.apart(ex)
# Out:
#       1           1
# - ───────── + ─────────
#   2⋅(a + 5)   2⋅(a + 3)

# %%
sp.apart(1/(a**3-8))
# Out:
#         a + 4             1
# - ───────────────── + ──────────
#      ⎛ 2          ⎞   12⋅(a - 2)
#   12⋅⎝a  + 2⋅a + 4⎠

# %% [markdown]
# ### 13.2.3 定義函數與建立函數物件

# %%
a,b,x=sp.symbols('a,b,x')

# %%
(a**2+3).subs({a:b**2})
# Out:
#  4
# b  + 3

# %%
f=sp.lambdify(a,a**2+3)

# %%
f(b**2)
# Out:
#  4
# b  + 3

# %%
f(a),f(3.2),f(sp.sin(a)+sp.E)
# Out:
# ⎛ 2                                      2    ⎞
# ⎝a  + 3, 13.240000000000002, (sin(a) + ℯ)  + 3⎠

# %%
f(np.array([-1,0,3,6]))
# Out:
# array([ 4,  3, 12, 39])

# %%
f=sp.lambdify([a,b],a**2+b**2)

# %%
f(3,4)
# Out:
# 25

# %%
f(sp.sin(x),sp.cos(x))
# Out:
#    2         2
# sin (x) + cos (x)

# %%
def g(x):
    t=4*x-1
    return sp.cos(t)**2+2

# %%
g(x)
# Out:
#    2
# cos (4⋅x - 1) + 2

# %%
g(x+sp.pi/3)
# Out:
#    2⎛          π⎞
# cos ⎜4⋅x - 1 + ─⎟ + 2
#     ⎝          3⎠

# %%
g(3.14)
# Out:
# 2.28615084419082

# %%
f=sp.Function('f')

# %%
f(x)**2+4*x
# Out:
#        2
# 4⋅x + f (x)

# %%
f(sp.sin(x)+2*x)
# Out:
# f(2⋅x + sin(x))

# %%
f(x).diff(x)
# Out:
# d
# ──(f(x))
# dx

# %%
f(x).diff(x,2).subs(x,0)
# Out:
# ⎛  2      ⎞│
# ⎜ d       ⎟│
# ⎜───(f(x))⎟│
# ⎜  2      ⎟│
# ⎝dx       ⎠│x=0

# %% [markdown]
# ## 13.3 解方程式

# %%
a,b,c,x,y=sp.symbols('a,b,c,x,y')

# %%
sp.solve(x**2+3*x-a, x)
# Out:
# ⎡    _________        _________    ⎤
# ⎢  ╲╱ 4⋅a + 9    3  ╲╱ 4⋅a + 9    3⎥
# ⎢- ─────────── - ─, ─────────── - ─⎥
# ⎣       2        2       2        2⎦

# %%
sp.solve([x+4*y-1,2*x-2*y-1], [x,y])
# Out:
# {x: 3/5, y: 1/10}

# %%
sp.solve([x**2+y-1,x-2*y+1],[x,y])
# Out:
# [(-1, 0), (1/2, 3/4)]

# %%
(x**2+y-1).subs({x:-1,y:0})
# Out:
# 0

# %%
(x-2*y+1).subs({x:-1,y:0})
# Out:
# 0

# %%
sp.solve(a*x**2+b*x+c,x)
# Out:
# ⎡        _____________   ⎛       _____________⎞ ⎤
# ⎢       ╱           2    ⎜      ╱           2 ⎟ ⎥
# ⎢-b + ╲╱  -4⋅a⋅c + b    -⎝b + ╲╱  -4⋅a⋅c + b  ⎠ ⎥
# ⎢─────────────────────, ────────────────────────⎥
# ⎣         2⋅a                     2⋅a           ⎦

# %%
sp.solve(sp.exp(x**2)-9,x)
# Out:
# ⎡   ________    ________⎤
# ⎣-╲╱ log(9) , ╲╱ log(9) ⎦

# %%
sp.solve(a**3+2*a**2-1,a)
# Out:
# ⎡      1   √5    √5   1⎤
# ⎢-1, - ─ + ──, - ── - ─⎥
# ⎣      2   2     2    2⎦

# %%
sp.nroots(a**3+2*a**2-1,4)
# Out:
# [-1.618, -1.0, 0.618]

# %%
f=4*sp.cos(3*x)-x**3

# %%
#sp.solve(f,x) # NotImplementedError: multiple generators [x, cos(3*x)]
                # No algorithms are implemented to solve equation -x**3 + 4*cos(3*x)

# %%
sp.plot(f,(x,-2,2),line_color='red')

# %%
sp.nsolve(f,x,1,prec=5)
# Out:
# 0.51239

# %%
sp.nsolve(f,x,-2)
# Out:
# -1.34997551856788

# %%
eq=sp.Eq(sp.sin(x)+sp.cos(x),1);eq
# Out:
# sin(x) + cos(x) = 1

# %%
sp.solve(eq,x)
# Out:
# ⎡   π⎤
# ⎢0, ─⎥
# ⎣   2⎦

# %%
sp.nsolve(eq,x,2)
# Out:
# 1.57079632679490

# %%
eq1=sp.Eq(x**2+y**2,1); eq1
# Out:
#  2    2
# x  + y  = 1

# %%
eq2=sp.Eq((x-2)**2+(y-1)**2,4); eq2
# Out:
#        2          2
# (x - 2)  + (y - 1)  = 4

# %%
sp.solve([eq1,eq2],[x,y])
# Out:
# [(0, 1), (4/5, -3/5)]

# %%
p1=sp.plot_implicit(eq1,(x,-1,4),(y,-2,3), line_color='r',aspect_ratio=(1,1),show=False)

# %%
p2=sp.plot_implicit(eq2,(x,-1,4),(y,-2,3), line_color='g',aspect_ratio=(1,1),show=False)

# %%
p1.extend(p2)
p1.show()

# %% [markdown]
# ## 13.4 微積分

# %% [markdown]
# ### 13.4.1 極限、微分與積分

# %%
x,y=sp.symbols('x,y')

# %%
lim=sp.Limit(sp.sin(x)/x, x, 0,dir='+-')
lim
# Out:
#     ⎛sin(x)⎞
# lim ⎜──────⎟
# x─→0⎝  x   ⎠

# %%
lim.doit()
# Out:
# 1

# %%
lim=sp.Limit((1+1/x)**x, x, sp.oo)
lim
# Out:
#            x
#     ⎛    1⎞
# lim ⎜1 + ─⎟
# x─→∞⎝    x⎠

# %%
lim.doit()
# Out:
# ℯ

# %%
sp.Eq(lim,lim.doit())
# Out:
#            x
#     ⎛    1⎞
# lim ⎜1 + ─⎟  = ℯ
# x─→∞⎝    x⎠

# %%
sp.limit(1/x,x,0,dir='-')
# Out:
# -∞

# %%
sp.limit(1/x,x,0,dir='+')
# Out:
# ∞

# %%
ex=x*sp.sin(x**2)+1

# %%
d=sp.Derivative(ex,x)
d
# Out:
# d ⎛     ⎛ 2⎞    ⎞
# ──⎝x⋅sin⎝x ⎠ + 1⎠
# dx

# %%
d.doit()
# Out:
#    2    ⎛ 2⎞      ⎛ 2⎞
# 2⋅x ⋅cos⎝x ⎠ + sin⎝x ⎠

# %%
sp.diff(ex,x)
# Out:
#    2    ⎛ 2⎞      ⎛ 2⎞
# 2⋅x ⋅cos⎝x ⎠ + sin⎝x ⎠

# %%
sp.diff(ex,x,2)
# Out:
#     ⎛     2    ⎛ 2⎞        ⎛ 2⎞⎞
# 2⋅x⋅⎝- 2⋅x ⋅sin⎝x ⎠ + 3⋅cos⎝x ⎠⎠

# %%
d=sp.Derivative(ex,x).subs(x,0)
d
# Out:
# ⎛d ⎛     ⎛ 2⎞    ⎞⎞│
# ⎜──⎝x⋅sin⎝x ⎠ + 1⎠⎟│
# ⎝dx               ⎠│x=0

# %%
d.doit()
# Out:
# 0

# %%
sp.diff(x**x,x)
# Out:
#  x
# x ⋅(log(x) + 1)

# %%
ex=x*sp.sin(x**2)+1

# %%
sp.integrate(ex,x)
# Out:
#        ⎛ 2⎞
#     cos⎝x ⎠
# x - ───────
#        2

# %%
i=sp.Integral(ex,(x,0,sp.pi))
i
# Out:
# π
# ⌠
# ⎮ ⎛     ⎛ 2⎞    ⎞
# ⎮ ⎝x⋅sin⎝x ⎠ + 1⎠ dx
# ⌡
# 0

# %%
i.doit()
# Out:
#      ⎛ 2⎞
#   cos⎝π ⎠   1
# - ─────── + ─ + π
#      2      2

# %%
i=sp.Integral(ex,(x,0,sp.pi))
i
# Out:
# π
# ⌠
# ⎮ ⎛     ⎛ 2⎞    ⎞
# ⎮ ⎝x⋅sin⎝x ⎠ + 1⎠ dx
# ⌡
# 0

# %%
i.doit()
# Out:
#      ⎛ 2⎞
#   cos⎝π ⎠   1
# - ─────── + ─ + π
#      2      2

# %%
i=sp.Integral(1/(1+x**2),(x,0,sp.oo))
i
# Out:
# ∞
# ⌠
# ⎮   1
# ⎮ ────── dx
# ⎮  2
# ⎮ x  + 1
# ⌡
# 0

# %%
i.doit()
# Out:
# π
# ─
# 2

# %%
i=sp.Integral(y/(1+x**2),(x,0,sp.oo),(y,0,1))
i
# Out:
# 1 ∞
# ⌠ ⌠
# ⎮ ⎮   y
# ⎮ ⎮ ────── dx dy
# ⎮ ⎮  2
# ⎮ ⎮ x  + 1
# ⌡ ⌡
# 0 0

# %%
i.doit()
# Out:
# π
# ─
# 4

# %% [markdown]
# ### 13.4.2 數列的加總與連乘

# %%
i,n,x=sp.symbols('i,n,x')

# %%
s1= sp.Sum(x**3, (x, 1, n))
s1
# Out:
#   n
#  ___
#  ╲
#   ╲    3
#   ╱   x
#  ╱
#  ‾‾‾
# x = 1

# %%
s1.doit().simplify()
# Out:
#  2 ⎛ 2          ⎞
# n ⋅⎝n  + 2⋅n + 1⎠
# ─────────────────
#         4

# %%
s2= sp.Sum((-1)**n*x**(2*n+1)/sp.factorial(2*n+1), (n, 1, sp.oo))
s2
# Out:
#   ∞
#  ____
#  ╲
#   ╲       n  2⋅n + 1
#    ╲  (-1) ⋅x
#    ╱  ──────────────
#   ╱     (2⋅n + 1)!
#  ╱
#  ‾‾‾‾
# n = 1

# %%
s2.doit().simplify()
# Out:
# -x + sin(x)

# %%
sp.summation(1/3**n,(n,1,sp.oo))
# Out:
# 1/2

# %%
sp.Product(n, (n, 1, 10)) # 10!
# Out:
#   10
# ─┬─┬─
#  │ │  n
#  │ │
# n = 1

# %%
sp.product(i/n**2, (i, 1, n))
# Out:
#     n
# ⎛1 ⎞
# ⎜──⎟ ⋅n!
# ⎜ 2⎟
# ⎝n ⎠

# %% [markdown]
# ### 13.4.3 泰勒級數

# %%
x=sp.symbols('x')

# %%
s1=sp.sin(x).series(x, 0, 10)
s1
# Out:
#      3     5     7       9
#     x     x     x       x       ⎛ 10⎞
# x - ── + ─── - ──── + ────── + O⎝x  ⎠
#     6    120   5040   362880

# %%
s2=sp.cos(x).series(x, 0, 10)
s2
# Out:
#      2    4     6      8
#     x    x     x      x      ⎛ 10⎞
# 1 - ── + ── - ─── + ───── + O⎝x  ⎠
#     2    24   720   40320

# %%
sp.expand(s1*s2)
# Out:
#        3      5      7      9
#     2⋅x    2⋅x    4⋅x    2⋅x     ⎛ 10⎞
# x - ──── + ──── - ──── + ──── + O⎝x  ⎠
#      3      15    315    2835

# %%
sp.exp(x).series(x, 1, 3).removeO()
# Out:
#          2
# ℯ⋅(x - 1)
# ────────── + ℯ⋅(x - 1) + ℯ
#     2

# %%
p0 = sp.plot(sp.sin(x), (x,0, 6), show=False,ylim=(-2,2),line_color='black')

# %%
for t,c in zip([2,4,6],['r','g','b']):
   s=sp.sin(x).series(x,0,t).removeO()
   p=sp.plot(s,(x,0,6),show=False,line_color=c)
   p0.extend(p)

# %%
p0.show()

# %% [markdown]
# ## 13.5 線性代數

# %%
a,b,c,x,y,z=sp.symbols('a,b,c,x,y,z')

# %%
sp.Matrix([[a,b,c]])
# Out:
# [a  b  c]

# %%
sp.Matrix([a,b,c])
# Out:
# ⎡a⎤
# ⎢ ⎥
# ⎢b⎥
# ⎢ ⎥
# ⎣c⎦

# %%
sp.Matrix(np.array([[0,1,2],[3,4,5]]))
# Out:
# ⎡0  1  2⎤
# ⎢       ⎥
# ⎣3  4  5⎦

# %%
sp.ones(2,3)
# Out:
# ⎡1  1  1⎤
# ⎢       ⎥
# ⎣1  1  1⎦

# %%
sp.eye(3)
# Out:
# ⎡1  0  0⎤
# ⎢       ⎥
# ⎢0  1  0⎥
# ⎢       ⎥
# ⎣0  0  1⎦

# %%
sp.diag(a,b,c)
# Out:
# ⎡a  0  0⎤
# ⎢       ⎥
# ⎢0  b  0⎥
# ⎢       ⎥
# ⎣0  0  c⎦

# %%
sp.diag(*[a,b,c])
# Out:
# ⎡a  0  0⎤
# ⎢       ⎥
# ⎢0  b  0⎥
# ⎢       ⎥
# ⎣0  0  c⎦

# %%
m1=sp.Matrix([[a,b,c],[x,y,z]])
m1
# Out:
# ⎡a  b  c⎤
# ⎢       ⎥
# ⎣x  y  z⎦

# %%
m1.T
# Out:
# ⎡a  x⎤
# ⎢    ⎥
# ⎢b  y⎥
# ⎢    ⎥
# ⎣c  z⎦

# %%
m2=sp.Matrix(3,2,[a,b,c,x,y,z])
m2
# Out:
# ⎡a  b⎤
# ⎢    ⎥
# ⎢c  x⎥
# ⎢    ⎥
# ⎣y  z⎦

# %%
m1*m2
# Out:
# ⎡ 2                              ⎤
# ⎢a  + b⋅c + c⋅y   a⋅b + b⋅x + c⋅z⎥
# ⎢                                ⎥
# ⎢                              2 ⎥
# ⎣a⋅x + c⋅y + y⋅z  b⋅x + x⋅y + z  ⎦

# %%
m1+m2.T
# Out:
# ⎡ 2⋅a   b + c  c + y⎤
# ⎢                   ⎥
# ⎣b + x  x + y   2⋅z ⎦

# %%
m1.multiply_elementwise(m2.T)
# Out:
# ⎡ 2           ⎤
# ⎢a    b⋅c  c⋅y⎥
# ⎢             ⎥
# ⎢           2 ⎥
# ⎣b⋅x  x⋅y  z  ⎦

# %%
m2*3
# Out:
# ⎡3⋅a  3⋅b⎤
# ⎢        ⎥
# ⎢3⋅c  3⋅x⎥
# ⎢        ⎥
# ⎣3⋅y  3⋅z⎦

# %%
m1.shape
# Out:
# (2, 3)

# %%
m1.row(0)
# Out:
# [a  b  c]

# %%
m1.col(-1)
# Out:
# ⎡c⎤
# ⎢ ⎥
# ⎣z⎦

# %%
m1.col_del(0)  
m1
# Out:
# ⎡b  c⎤
# ⎢    ⎥
# ⎣y  z⎦

# %%
m1.row_insert(2,sp.Matrix([[a,a**2]]))
# Out:
# ⎡b  c ⎤
# ⎢     ⎥
# ⎢y  z ⎥
# ⎢     ⎥
# ⎢    2⎥
# ⎣a  a ⎦

# %%
m=sp.Matrix([[0,a],[4,0]])
m
# Out:
# ⎡0  a⎤
# ⎢    ⎥
# ⎣4  0⎦

# %%
m**2
# Out:
# ⎡4⋅a   0 ⎤
# ⎢        ⎥
# ⎣ 0   4⋅a⎦

# %%
m.inv()
# Out:
# ⎡0  1/4⎤
# ⎢      ⎥
# ⎢1     ⎥
# ⎢─   0 ⎥
# ⎣a     ⎦

# %%
m.eigenvals()
# Out:
# {-2⋅√a: 1, 2⋅√a: 1}

# %%
m.eigenvects()
# Out:
# ⎡⎛          ⎡⎡-√a ⎤⎤⎞  ⎛         ⎡⎡√a⎤⎤⎞⎤
# ⎢⎜          ⎢⎢────⎥⎥⎟  ⎜         ⎢⎢──⎥⎥⎟⎥
# ⎢⎜-2⋅√a, 1, ⎢⎢ 2  ⎥⎥⎟, ⎜2⋅√a, 1, ⎢⎢2 ⎥⎥⎟⎥
# ⎢⎜          ⎢⎢    ⎥⎥⎟  ⎜         ⎢⎢  ⎥⎥⎟⎥
# ⎣⎝          ⎣⎣ 1  ⎦⎦⎠  ⎝         ⎣⎣1 ⎦⎦⎠⎦

# %%
m=sp.Matrix([[a,b],[0,c]])
v=sp.Matrix([4,9])

# %%
sp.linsolve([m,v])
# Out:
# ⎧⎛-9⋅b + 4⋅c  9⎞⎫
# ⎨⎜──────────, ─⎟⎬
# ⎩⎝   a⋅c      c⎠⎭

# %% [markdown]
# ## 13.6 解微分方程式

# %%
a,b,c,x,y=sp.symbols('a,b,c,x,y')

# %%
f=sp.Function('f')

# %%
eqn=sp.Eq(f(x).diff(x)-f(x),sp.cos(x))
eqn
# Out:
#         d
# -f(x) + ──(f(x)) = cos(x)
#         dx

# %%
eqn.lhs
# Out:
#         d
# -f(x) + ──(f(x))
#         dx

# %%
eqn.rhs
# Out:
# cos(x)

# %%
sp.dsolve(eqn)
# Out:
#        ⎛      -x           -x       ⎞
#        ⎜     ℯ  ⋅sin(x)   ℯ  ⋅cos(x)⎟  x
# f(x) = ⎜C₁ + ────────── - ──────────⎟⋅ℯ
#        ⎝         2            2     ⎠

# %%
sp.dsolve(eqn,ics={f(0): 3})
# Out:
#        ⎛     -x           -x       ⎞
#        ⎜7   ℯ  ⋅sin(x)   ℯ  ⋅cos(x)⎟  x
# f(x) = ⎜─ + ────────── - ──────────⎟⋅ℯ
#        ⎝2       2            2     ⎠

# %%
eqn=sp.Eq(f(x).diff(x,2)+2*f(x),sp.sin(x))
eqn
# Out:
#            2
#           d
# 2⋅f(x) + ───(f(x)) = sin(x)
#            2
#          dx

# %%
fp=sp.diff(f(x), x).subs(x,0)
fp
# Out:
# ⎛d       ⎞│
# ⎜──(f(x))⎟│
# ⎝dx      ⎠│x=0

# %%
sol=sp.dsolve(eqn,ics={f(0): 3,fp: 0})
sol
# Out:
#                 √2⋅sin(√2⋅x)
# f(x) = sin(x) - ──────────── + 3⋅cos(√2⋅x)
#                      2

# %%
sp.plot(sol.rhs,(x,0,20))

# %%
u=sp.Function('u')
v=sp.Function('v')
t=sp.symbols('t')

# %%
eq1=sp.Eq(u(t).diff(t),5*u(t)-3*v(t))
eq1
# Out:
# d
# ──(u(t)) = 5⋅u(t) - 3⋅v(t)
# dt

# %%
eq2=sp.Eq(v(t).diff(t),-6*u(t)+2*v(t))
eq2
# Out:
# d
# ──(v(t)) = -6⋅u(t) + 2⋅v(t)
# dt

# %%
sp.dsolve([eq1,eq2])
# Out:
# ⎡           -t                                   ⎤
# ⎢       C₁⋅ℯ         8⋅t             -t       8⋅t⎥
# ⎢u(t) = ────── - C₂⋅ℯ   , v(t) = C₁⋅ℯ   + C₂⋅ℯ   ⎥
# ⎣         2                                      ⎦

# %%
sol=sp.dsolve([eq1,eq2],ics={u(0):3,v(0):7})
sol
# Out:
# ⎡          8⋅t       -t          8⋅t       -t⎤
# ⎢         ℯ      10⋅ℯ           ℯ      20⋅ℯ  ⎥
# ⎢u(t) = - ──── + ──────, v(t) = ──── + ──────⎥
# ⎣          3       3             3       3   ⎦
