# %% [markdown]
# <font color=#1E8449>☘ </font> 注意事項
# 1. 如果您使用 Colab，在您熟悉 Colab 的操作環境之後，建議把介面改成英文版，以便讓程式碼有最好的顯示效果
#  * 選擇 Colab 功能表裡的 <font color=#E59866>說明</font> - <font color=#E59866>查看英文版本</font> 即可將介面改成英文版
#  * 要改回中文版，請關掉目前開啟的 Colab 網頁，再重新開啟您執行的 Colab 檔案即可（Colab 預設為中文版）
# 2. 建議選擇暗色背景，長時間撰寫程式時眼睛會比較舒服
#  * 在 Colab 裡選擇 <font color=#E59866>Tools（工具）</font> - <font color=#E59866> Settings （設定）</font> - <font color=#E59866> Site（網站）</font> - <font color=#E59866> Theme （主題）</font> - <font color=#E59866> Dark </font>
#  * 在 Jupyter lab 中選擇 <font color=#E59866> Settings </font> - <font color=#E59866> JupyterLab theme </font> - <font color=#E59866> JupyerterLab Dark </font>

# %% [markdown]
# ## Chap 12 使用 Pandas 處理數據資料

# %% [markdown]
# ## 12.1 Pandas 的基本認識

# %% [markdown]
# ### 12.1.1 一維的 Series 資料型別

# %%
import pandas as pd
import numpy as np

# %%
s0=pd.Series([4.3,7.24,8.5])

# %%
s0
# Out:
# 0    4.30
# 1    7.24
# 2    8.50
# dtype: float64

# %%
s0.ndim
# Out:
# 1

# %%
s0.shape
# Out:
# (3,)

# %%
s0.size
# Out:
# 3

# %%
s0.dtype
# Out:
# dtype('float64')

# %%
pd.Series([4,'a',12]).dtype
# Out:
# dtype('O')

# %%
s0.values
# Out:
# array([4.3 , 7.24, 8.5 ])

# %%
s0.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
s0[0],s0[1]
# Out:
# (4.3, 7.24)

# %%
s0[1:]
# Out:
# 1    7.24
# 2    8.50
# dtype: float64

# %%
s0[[0,2]]
# Out:
# 0    4.3
# 2    8.5
# dtype: float64

# %%
s0[4]=7; s0
# Out:
# 0    4.30
# 1    7.24
# 2    8.50
# 4    7.00
# dtype: float64

# %%
s0['candy']=12; s0
# Out:
# 0         4.30
# 1         7.24
# 2         8.50
# 4         7.00
# candy    12.00
# dtype: float64

# %%
s0.index
# Out:
# Index([0, 1, 2, 4, 'candy'], dtype='object')

# %% [markdown]
# <font color=#1EA004>☘ </font> 在建立 Series 物件時就賦予特定的索引

# %%
s1=pd.Series([4,7,8],index=['a','b','c'])

# %%
s1
# Out:
# a    4
# b    7
# c    8
# dtype: int64

# %%
s1['a']
# Out:
# 4

# %%
s1['b']=-5; s1
# Out:
# a    4
# b   -5
# c    8
# dtype: int64

# %%
s1[0]
# Out:
# 4

# %%
s1.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
'a' in s1
# Out:
# True

# %%
0 in s1
# Out:
# False

# %%
8 in s1
# Out:
# False

# %%
s1.where(s1>0)
# Out:
# a    4.0
# b    NaN
# c    8.0
# dtype: float64

# %%
s1.where(s1>0,0)
# Out:
# a    4
# b    0
# c    8
# dtype: int64

# %%
d0={'coffee':50,'tea':30,'juice':60}

# %%
s2=pd.Series(d0)

# %%
s2
# Out:
# coffee    50
# tea       30
# juice     60
# dtype: int64

# %%
s3=pd.Series(d0,index=['tea','cola','coffee'])  
s3
# Out:
# tea       30.0
# cola       NaN
# coffee    50.0
# dtype: float64

# %%
s3.isna()
# Out:
# tea       False
# cola       True
# coffee    False
# dtype: bool

# %%
s3.notna()
# Out:
# tea        True
# cola      False
# coffee     True
# dtype: bool

# %%
s3.index=['tea','juice','candy']

# %%
s3
# Out:
# tea      30.0
# juice     NaN
# candy    50.0
# dtype: float64

# %%
s3.fillna(0)
# Out:
# tea      30.0
# juice     0.0
# candy    50.0
# dtype: float64

# %%
s3.dropna()
# Out:
# tea      30.0
# candy    50.0
# dtype: float64

# %% [markdown]
# ### 12.1.2 二維的 DataFrame

# %%
ar=np.arange(6).reshape((2,3))

# %%
pd.DataFrame(ar)
# Out:
#    0  1  2
# 0  0  1  2
# 1  3  4  5

# %%
pd.DataFrame(ar,columns=['a','b','c'])
# Out:
#    a  b  c
# 0  0  1  2
# 1  3  4  5

# %%
pd.DataFrame(ar,index=['Java','C++'])
# Out:
#       0  1  2
# Java  0  1  2
# C++   3  4  5

# %%
data={'Math':   [98,99,38,97],
      'Biology':[78,89,45,67],
      'English':[87,98,86,98]}

# %%
d0=pd.DataFrame(data); d0
# Out:
#    Math  Biology  English
# 0    98       78       87
# 1    99       89       98
# 2    38       45       86
# 3    97       67       98

# %%
d0.head(3)
# Out:
#    Math  Biology  English
# 0    98       78       87
# 1    99       89       98
# 2    38       45       86

# %%
d0.tail(2)
# Out:
#    Math  Biology  English
# 2    38       45       86
# 3    97       67       98

# %%
d0.dtypes
# Out:
# Math       int64
# Biology    int64
# English    int64
# dtype: object

# %%
d0.shape
# Out:
# (4, 3)

# %%
pd.DataFrame(data,columns=['English','Math','Biology'])
# Out:
#    English  Math  Biology
# 0       87    98       78
# 1       98    99       89
# 2       86    38       45
# 3       98    97       67

# %%
d1=pd.DataFrame(data,
                columns=['English','Math','Python'],
                index=['Tom','Jerry','Mary','Bob'])

# %%
d1
# Out:
#        English  Math Python
# Tom         87    98    NaN
# Jerry       98    99    NaN
# Mary        86    38    NaN
# Bob         98    97    NaN

# %%
d1.columns
# Out:
# Index(['English', 'Math', 'Python'], dtype='object')

# %%
d1.index
# Out:
# Index(['Tom', 'Jerry', 'Mary', 'Bob'], dtype='object')

# %%
d1.columns[2]
# Out:
# 'Python'

# %%
d1.index[0]
# Out:
# 'Tom'

# %%
d1['Math']
# Out:
# Tom      98
# Jerry    99
# Mary     38
# Bob      97
# Name: Math, dtype: int64

# %%
d1.English
# Out:
# Tom      87
# Jerry    98
# Mary     86
# Bob      98
# Name: English, dtype: int64

# %%
d1['Python']=[78,99,43,78]; d1
# Out:
#        English  Math  Python
# Tom         87    98      78
# Jerry       98    99      99
# Mary        86    38      43
# Bob         98    97      78

# %%
s=pd.Series([77,44],index=['Bob','Mary'])

# %%
d1['Math']=s; d1
# Out:
#        English  Math  Python
# Tom         87   NaN      78
# Jerry       98   NaN      99
# Mary        86  44.0      43
# Bob         98  77.0      78

# %%
d1['Missing']=d1.Math.isna(); d1
# Out:
#        English  Math  Python  Missing
# Tom         87   NaN      78     True
# Jerry       98   NaN      99     True
# Mary        86  44.0      43    False
# Bob         98  77.0      78    False

# %%
del d1['Missing']; d1
# Out:
#        English  Math  Python
# Tom         87   NaN      78
# Jerry       98   NaN      99
# Mary        86  44.0      43
# Bob         98  77.0      78

# %%
a=np.array([np.nan,12,40]); a
# Out:
# array([nan, 12., 40.])

# %%
a.dtype
# Out:
# dtype('float64')

# %%
d1.values
# Out:
# array([[87., nan, 78.],
#        [98., nan, 99.],
#        [86., 44., 43.],
#        [98., 77., 78.]])

# %%
d1.T
# Out:
#           Tom  Jerry  Mary   Bob
# English  87.0   98.0  86.0  98.0
# Math      NaN    NaN  44.0  77.0
# Python   78.0   99.0  43.0  78.0

# %%
d=pd.DataFrame(
    [[63,65,77],[63,None,39]],
    columns=['Java','C++','VB']); d
# Out:
#    Java   C++  VB
# 0    63  65.0  77
# 1    63   NaN  39

# %%
d['C++']
# Out:
# 0    65.0
# 1     NaN
# Name: C++, dtype: float64

# %%
d['C++'][1]
# Out:
# nan

# %%
d.isna()
# Out:
#     Java    C++     VB
# 0  False  False  False
# 1  False   True  False

# %%
d.fillna(0)
# Out:
#    Java   C++  VB
# 0    63  65.0  77
# 1    63   0.0  39

# %%
d.where(d<60)
# Out:
#    Java  C++    VB
# 0   NaN  NaN   NaN
# 1   NaN  NaN  39.0

# %% [markdown]
# ## 12.2 Series 和 DataFrame 的運算

# %% [markdown]
# ### 12.2.1 元素的選取

# %%
s0=pd.Series([6,7,8],
            index=['a','b','c']); s0
# Out:
# a    6
# b    7
# c    8
# dtype: int64

# %%
s0[2], s0[-1], s0['c']
# Out:
# (8, 8, 8)

# %%
s0[1:]
# Out:
# b    7
# c    8
# dtype: int64

# %%
s0[[2,0,1]]
# Out:
# c    8
# a    6
# b    7
# dtype: int64

# %%
s0.iloc[0],s0.iloc[-1]
# Out:
# (6, 8)

# %%
s0.iloc[::-1]
# Out:
# c    8
# b    7
# a    6
# dtype: int64

# %%
s0.loc['c']
# Out:
# 8

# %%
s1=pd.Series([6,7,8])

# %%
s1[0]
# Out:
# 6

# %%
s1[1:]
# Out:
# 1    7
# 2    8
# dtype: int64

# %%
# s1[-1]  # Pandas會不知道 -1是索引，還是用來表示最後一個位置

# %%
d=pd.DataFrame(np.arange(12).reshape(3,4),
               index=['a','b','c'],
               columns=['w','x','y','z'])

# %%
d
# Out:
#    w  x   y   z
# a  0  1   2   3
# b  4  5   6   7
# c  8  9  10  11

# %%
d['w']
# Out:
# a    0
# b    4
# c    8
# Name: w, dtype: int64

# %%
d[['w','y','x']]
# Out:
#    w   y  x
# a  0   2  1
# b  4   6  5
# c  8  10  9

# %%
d[1:]
# Out:
#    w  x   y   z
# b  4  5   6   7
# c  8  9  10  11

# %%
d[0:2]
# Out:
#    w  x  y  z
# a  0  1  2  3
# b  4  5  6  7

# %%
d[0:2]['x']
# Out:
# a    1
# b    5
# Name: x, dtype: int64

# %%
d[0:2][['x','w','z']]
# Out:
#    x  w  z
# a  1  0  3
# b  5  4  7

# %%
d.loc['a','x']
# Out:
# 1

# %%
d.iloc[0,2]
# Out:
# 2

# %%
d.loc['a',['w','x']]
# Out:
# w    0
# x    1
# Name: a, dtype: int64

# %%
d.loc[['a','c'],['w','x']]
# Out:
#    w  x
# a  0  1
# c  8  9

# %%
d.loc[:,['w','x']]
# Out:
#    w  x
# a  0  1
# b  4  5
# c  8  9

# %%
d.loc[['a','b']]
# Out:
#    w  x  y  z
# a  0  1  2  3
# b  4  5  6  7

# %%
d.iloc[:2,1:]
# Out:
#    x  y  z
# a  1  2  3
# b  5  6  7

# %%
d.iloc[[1,2],[2,3,1]]
# Out:
#     y   z  x
# b   6   7  5
# c  10  11  9

# %%
d.iloc[-1,2:]
# Out:
# y    10
# z    11
# Name: c, dtype: int64

# %% [markdown]
# ### 12.2.2 提取符合特定條件的元素

# %% [markdown]
# <font color=#1EA004>☘ </font> For Series objects

# %%
s=pd.Series([23,55,32])

# %%
s<40
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
s[s<40]
# Out:
# 0    23
# 2    32
# dtype: int64

# %% [markdown]
# * For DataFrame objects

# %%
score=[[37,65,54],
       [38,87,77],
       [65,77,90]]
name=['Tom','Jerry','Mary'];
course=['Math','English','Biology']

# %%
d=pd.DataFrame(score,
               index=name,
               columns=course)

# %%
d
# Out:
#        Math  English  Biology
# Tom      37       65       54
# Jerry    38       87       77
# Mary     65       77       90

# %%
d['Math']>=60
# Out:
# Tom      False
# Jerry    False
# Mary      True
# Name: Math, dtype: bool

# %%
d[d['Math']>=60]
# Out:
#       Math  English  Biology
# Mary    65       77       90

# %%
d>=60
# Out:
#         Math  English  Biology
# Tom    False     True    False
# Jerry  False     True     True
# Mary    True     True     True

# %%
d.loc['Jerry']
# Out:
# Math       38
# English    87
# Biology    77
# Name: Jerry, dtype: int64

# %%
d.loc['Jerry']>=60
# Out:
# Math       False
# English     True
# Biology     True
# Name: Jerry, dtype: bool

# %%
d.columns
# Out:
# Index(['Math', 'English', 'Biology'], dtype='object')

# %%
list(d.columns)
# Out:
# ['Math', 'English', 'Biology']

# %%
d.columns[0]
# Out:
# 'Math'

# %%
d.columns[[True,True,False]]
# Out:
# Index(['Math', 'English'], dtype='object')

# %%
d.columns[d.loc['Jerry']>=60]
# Out:
# Index(['English', 'Biology'], dtype='object')

# %%
d.index[d['Math']<60]
# Out:
# Index(['Tom', 'Jerry'], dtype='object')

# %%
(d>=60).all(axis=0)
# Out:
# Math       False
# English     True
# Biology    False
# dtype: bool

# %%
(d>=60).all(axis=1)
# Out:
# Tom      False
# Jerry    False
# Mary      True
# dtype: bool

# %%
(d.Math<60) | (d.Biology<60)
# Out:
# Tom       True
# Jerry     True
# Mary     False
# dtype: bool

# %%
d[d<60]=60;d
# Out:
#        Math  English  Biology
# Tom      60       65       60
# Jerry    60       87       77
# Mary     65       77       90

# %% [markdown]
# ### 12.2.3 索引值的重排

# %%
s=pd.Series([8,12],index=['c','a'])

# %%
s
# Out:
# c     8
# a    12
# dtype: int64

# %%
s.reindex(['a','b','c'])
# Out:
# a    12.0
# b     NaN
# c     8.0
# dtype: float64

# %%
d=pd.DataFrame([[1,2,3],
                [4,5,6]],
              index=['a','b'],
              columns=['x','y','z'])

# %%
d
# Out:
#    x  y  z
# a  1  2  3
# b  4  5  6

# %%
d.reindex(list('abc'))
# Out:
#      x    y    z
# a  1.0  2.0  3.0
# b  4.0  5.0  6.0
# c  NaN  NaN  NaN

# %%
d.reindex(columns=['x','y','w'])
# Out:
#    x  y   w
# a  1  2 NaN
# b  4  5 NaN

# %%
d.reindex(list('abc'),
          columns=['w','x','y'])
# Out:
#     w    x    y
# a NaN  1.0  2.0
# b NaN  4.0  5.0
# c NaN  NaN  NaN

# %% [markdown]
# ### 12.2.4 刪除與插入列或欄

# %%
s=pd.Series([12,4,6,11])

# %%
s.drop(2)
# Out:
# 0    12
# 1     4
# 3    11
# dtype: int64

# %%
s.drop([1,3])
# Out:
# 0    12
# 2     6
# dtype: int64

# %%
s.append(pd.Series([90,100]))
# Out:
# 0     12
# 1      4
# 2      6
# 3     11
# 0     90
# 1    100
# dtype: int64

# %%
s.append(pd.Series([90,100]),ignore_index=True)
# Out:
# 0     12
# 1      4
# 2      6
# 3     11
# 4     90
# 5    100
# dtype: int64

# %%
d=pd.DataFrame([[1,2,3,4],[4,5,6,7]])

# %%
d
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  4  5  6  7

# %%
d.drop([0])
# Out:
#    0  1  2  3
# 1  4  5  6  7

# %%
d.drop([0,1],axis=1)
# Out:
#    2  3
# 0  3  4
# 1  6  7

# %%
d
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  4  5  6  7

# %%
d.append(pd.DataFrame([[9,9,9,9]]))
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  4  5  6  7
# 0  9  9  9  9

# %%
d.drop([0,1],axis=1,inplace=True)

# %%
d
# Out:
#    2  3
# 0  3  4
# 1  6  7

# %%
d=pd.DataFrame([[1,2],
                [3,4]],
              index=['a','b'],
              columns=['x','y'])

# %%
d.insert(1,'v',[9,8])

# %%
d
# Out:
#    x  v  y
# a  1  9  2
# b  3  8  4

# %% [markdown]
# ### 12.2.5 四則運算與其它函數的運算

# %%
s1=pd.Series([2,9,1],
             index=['a','c','d'])

# %%
s2=pd.Series([3,2],index=['a','d'])

# %%
s1+s2
# Out:
# a    5.0
# c    NaN
# d    3.0
# dtype: float64

# %%
s1.add(s2)
# Out:
# a    5.0
# c    NaN
# d    3.0
# dtype: float64

# %%
s1.add(s2,fill_value=0)
# Out:
# a    5.0
# c    9.0
# d    3.0
# dtype: float64

# %%
s1.mul(s2)
# Out:
# a    6.0
# c    NaN
# d    2.0
# dtype: float64

# %%
s3=s1.append(s2); s3
# Out:
# a    2
# c    9
# d    1
# a    3
# d    2
# dtype: int64

# %%
s3['a']
# Out:
# a    2
# a    3
# dtype: int64

# %%
s3.index.duplicated()
# Out:
# array([False, False, False,  True,  True])

# %%
s3[~s3.index.duplicated()]
# Out:
# a    2
# c    9
# d    1
# dtype: int64

# %%
np.sqrt(s1)
# Out:
# a    1.414214
# c    3.000000
# d    1.000000
# dtype: float64

# %%
d1=pd.DataFrame([[10,15],
                 [20,30]],
                columns=['a','b'],
                index=['x','y'])

# %%
d1
# Out:
#     a   b
# x  10  15
# y  20  30

# %%
d2=pd.DataFrame([[25,40,55],
                 [25,50,40]],
                columns=['a','b','c'],
                index=['x','y'])

# %%
d2
# Out:
#     a   b   c
# x  25  40  55
# y  25  50  40

# %%
d1+d2
# Out:
#     a   b   c
# x  35  55 NaN
# y  45  80 NaN

# %%
d1.add(d2,fill_value=0)
# Out:
#     a   b     c
# x  35  55  55.0
# y  45  80  40.0

# %%
d1.sub(d2)
# Out:
#     a   b   c
# x -15 -25 NaN
# y  -5 -20 NaN

# %%
np.max(d2)
# Out:
# a    25
# b    50
# c    55
# dtype: int64

# %%
np.max(d2.T)
# Out:
# x    55
# y    50
# dtype: int64

# %%
np.average(d2,axis=0)
# Out:
# array([25. , 45. , 47.5])

# %%
np.sum(d2,axis=1)
# Out:
# x    120
# y    115
# dtype: int64

# %% [markdown]
# ## 12.3 排序與統計函數

# %% [markdown]
# ### 12.3.1 排序函數

# %%
s=pd.Series([4,3,8],
            index=['c','a','b'])
s
# Out:
# c    4
# a    3
# b    8
# dtype: int64

# %%
s.sort_index()  # sort index
# Out:
# a    3
# b    8
# c    4
# dtype: int64

# %%
s.sort_values()   # sort values
# Out:
# a    3
# c    4
# b    8
# dtype: int64

# %%
d=pd.DataFrame([[40,60,50],
                [50,70,62]],
               columns=['S','L','M'],
               index=['tea','coffee'])

# %%
d
# Out:
#          S   L   M
# tea     40  60  50
# coffee  50  70  62

# %%
d.sort_index()
# Out:
#          S   L   M
# coffee  50  70  62
# tea     40  60  50

# %%
d.sort_index(axis=1)
# Out:
#          L   M   S
# tea     60  50  40
# coffee  70  62  50

# %%
d.sort_index(axis=1,ascending=False)
# Out:
#          S   M   L
# tea     40  50  60
# coffee  50  62  70

# %%
d.sort_values(by='L',ascending=False)
# Out:
#          S   L   M
# coffee  50  70  62
# tea     40  60  50

# %%
d.sort_values(by='coffee',axis=1)
# Out:
#          S   M   L
# tea     40  50  60
# coffee  50  62  70

# %% [markdown]
# ### 12.3.2 統計函數

# %%
d=pd.DataFrame([[3,5,7],
                [8,9,12]],
               index=['x','y'],
               columns=['a','b','c'])

# %%
d
# Out:
#    a  b   c
# x  3  5   7
# y  8  9  12

# %%
d.count()
# Out:
# a    2
# b    2
# c    2
# dtype: int64

# %%
d.count(axis=1)
# Out:
# x    3
# y    3
# dtype: int64

# %%
d.describe()
# Out:
#               a         b          c
# count  2.000000  2.000000   2.000000
# mean   5.500000  7.000000   9.500000
# std    3.535534  2.828427   3.535534
# min    3.000000  5.000000   7.000000
# 25%    4.250000  6.000000   8.250000
# 50%    5.500000  7.000000   9.500000
# 75%    6.750000  8.000000  10.750000
# max    8.000000  9.000000  12.000000

# %%
d.sum()
# Out:
# a    11
# b    14
# c    19
# dtype: int64

# %%
d.sum(axis=1)
# Out:
# x    15
# y    29
# dtype: int64

# %%
d.values.sum()
# Out:
# 44

# %%
d.mean()
# Out:
# a    5.5
# b    7.0
# c    9.5
# dtype: float64

# %%
d.median(axis=1)
# Out:
# x    5.0
# y    9.0
# dtype: float64

# %%
d.std()
# Out:
# a    3.535534
# b    2.828427
# c    3.535534
# dtype: float64

# %%
d.var()
# Out:
# a    12.5
# b     8.0
# c    12.5
# dtype: float64

# %%
d=pd.DataFrame([[3,5,None],
                [8,6,   3]],
               index=['x','y'],
               columns=['a','b','c'])

# %%
d
# Out:
#    a  b    c
# x  3  5  NaN
# y  8  6  3.0

# %%
d.count(axis=1)
# Out:
# x    2
# y    3
# dtype: int64

# %%
d.sum()    # treat nan as zero
# Out:
# a    11.0
# b    11.0
# c     3.0
# dtype: float64

# %%
d.sum(axis=1)
# Out:
# x     8.0
# y    17.0
# dtype: float64

# %%
d.sum(skipna=False,axis=1)
# Out:
# x     NaN
# y    17.0
# dtype: float64

# %% [markdown]
# ## 12.4 Pandas 的繪圖函數

# %%
s=pd.Series([55,30,45],
    index=['coffee','tea','juice'])

# %%
s.plot(kind='pie', autopct='%1.1f%%',
       title='Sales',label='June')

# %%
d=pd.DataFrame([[50,60,80],[45,70,85]],
               columns=['S','M','L'],
               index=['red','green'])

# %%
d
# Out:
#         S   M   L
# red    50  60  80
# green  45  70  85

# %%
d.plot(kind='bar',
       xlabel='Color',ylabel='Price')

# %% [markdown]
# ## 12.5 存取 csv 檔與 pickle 檔

# %%
d=pd.DataFrame([[50,60,80],
                [45,70,85]],
               columns=['S','M','L'],
               index=['red','greed'])

# %%
d
# Out:
#         S   M   L
# red    50  60  80
# greed  45  70  85

# %%
d.to_csv('price.csv')

# %%
# !more price.csv
# Out:
# ,S,M,L
# red,50,60,80
# greed,45,70,85

# %%
pd.read_csv('price.csv')
# Out:
#   Unnamed: 0   S   M   L
# 0        red  50  60  80
# 1      greed  45  70  85

# %%
pd.read_csv('price.csv',index_col=0)
# Out:
#         S   M   L
# red    50  60  80
# greed  45  70  85

# %%
pd.read_csv('price.csv',index_col=0,nrows=1)
# Out:
#       S   M   L
# red  50  60  80

# %%
d.to_csv('price2.csv',header=None)

# %%
# !more price2.csv
# Out:
# red,50,60,80
# greed,45,70,85

# %%
pd.read_csv('price2.csv',header=None,usecols=[1,2,3])
# Out:
#     1   2   3
# 0  50  60  80
# 1  45  70  85

# %%
d.to_csv('price3.csv',index=None)

# %%
! more price3.csv
# Out:
# S,M,L
# 50,60,80
# 45,70,85

# %%
pd.read_csv('price3.csv')
# Out:
#     S   M   L
# 0  50  60  80
# 1  45  70  85

# %%
d.to_pickle('price4')

# %%
d2=pd.read_pickle('price4')

# %%
d2
# Out:
#         S   M   L
# red    50  60  80
# greed  45  70  85

# %%
d2.eq(d)
# Out:
#           S     M     L
# red    True  True  True
# greed  True  True  True

# %%
d2.eq(d).all(axis=None)
# Out:
# True
