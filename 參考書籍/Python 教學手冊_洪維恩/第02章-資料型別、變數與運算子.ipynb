# %% [markdown]
# <font color=#1E8449>☘ </font> 注意事項
# 1. 如果您使用 Colab，在您熟悉 Colab 的操作環境之後，建議把介面改成英文版，以便讓程式碼有最好的顯示效果
#  * 選擇 Colab 功能表裡的 <font color=#E59866>說明</font> - <font color=#E59866>查看英文版本</font> 即可將介面改成英文版
#  * 要改回中文版，請關掉目前開啟的 Colab 網頁，再重新開啟您執行的 Colab 檔案即可（Colab 預設為中文版）
# 2. 建議選擇暗色背景，長時間撰寫程式時眼睛會比較舒服
#  * 在 Colab 裡選擇 <font color=#E59866>Tools（工具）</font> - <font color=#E59866> Settings （設定）</font> - <font color=#E59866> Site（網站）</font> - <font color=#E59866> Theme （主題）</font> - <font color=#E59866> Dark </font>
#  * 在 Jupyter lab 中選擇 <font color=#E59866> Settings </font> - <font color=#E59866> JupyterLab theme </font> - <font color=#E59866> JupyerterLab Dark </font>

# %% [markdown]
# ## Chap 02 資料型別、變數與運算子

# %% [markdown]
# ### 2.1 簡單的資料型別

# %% [markdown]
# #### 2.1.1 數值型別

# %% [markdown]
# <font color=#1E8449>☘ </font>  整數 (Integer)

# %%
6+20
# Out:
# 26

# %%
1024**9
# Out:
# 1237940039285380274899124224

# %%
type(6)
# Out:
# int

# %%
0b1100
# Out:
# 12

# %%
0b1001000100010101001010001000
# Out:
# 152130184

# %%
0o16
# Out:
# 14

# %%
# 0o178

# %%
0x8a
# Out:
# 138

# %%
0b10000-0xb
# Out:
# 5

# %%
type(0b10000)
# Out:
# int

# %% [markdown]
# <font color=#1E8449>☘ </font>  浮點數

# %%
type(3.14)
# Out:
# float

# %%
type(5.)
# Out:
# float

# %%
3.2+4
# Out:
# 7.2

# %%
2.34e5
# Out:
# 234000.0

# %%
6.78e-3
# Out:
# 0.00678

# %%
2.56e-400
# Out:
# 0.0

# %%
3.14e310
# Out:
# inf

# %% [markdown]
# <font color=#1E8449>☘ </font>  複數

# %%
6j
# Out:
# 6j

# %%
# 2+j

# %%
2+1j
# Out:
# (2+1j)

# %%
z= 5 + 3j

# %%
z - 12j
# Out:
# (5-9j)

# %%
z.real
# Out:
# 5.0

# %%
z.imag
# Out:
# 3.0

# %%
type(z)
# Out:
# complex

# %% [markdown]
# <font color=#1E8449>☘ </font>  布林 (Boolean)

# %%
1.5>4
# Out:
# False

# %%
5>3
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
128>0b100011
# Out:
# True

# %%
True + 1
# Out:
# 2

# %%
False + True
# Out:
# 1

# %% [markdown]
# #### 2.1.2 字串型別

# %%
'a string'
# Out:
# 'a string'

# %%
print('a string')
# Out:
# a string

# %%
"another string"
# Out:
# 'another string'

# %%
s = 'Hello Python'

# %%
type(s)
# Out:
# str

# %%
type('y')
# Out:
# str

# %%
'''
This is a
multiple line string
'''
# Out:
# '\nThis is a\nmultiple line string\n'

# %%
"""A single line string"""
# Out:
# 'A single line string'

# %%
a = 12

# %%
type(a)
# Out:
# int

# %%
a = 3.14

# %%
type(a)
# Out:
# float

# %%
a = b = c = 12

# %%
print(a, b, c)
# Out:
# 12 12 12

# %%
a, b, c = 10, 3.14, 'Python'

# %%
print(a, b, c)
# Out:
# 10 3.14 Python

# %%
age = 20; name = 'Python'

# %%
print(age, name)
# Out:
# 20 Python

# %% [markdown]
# * Python 的常數

# %%
PI = 3.14159

# %%
MAX_SIZE = 256

# %%
True + 2
# Out:
# 3

# %%
# True = 10

# %% [markdown]
# ### 2.3 常用的運算子

# %% [markdown]
# #### 2.3.1 算術運算子

# %%
5 + 4
# Out:
# 9

# %%
+50
# Out:
# 50

# %%
-100
# Out:
# -100

# %%
20 * 4
# Out:
# 80

# %%
60 / 4
# Out:
# 15.0

# %%
20 // 3
# Out:
# 6

# %%
20 % 3
# Out:
# 2

# %%
12 % 3.5
# Out:
# 1.5

# %%
2 ** 10
# Out:
# 1024

# %%
2 ** 0.5
# Out:
# 1.4142135623730951

# %% [markdown]
# #### 2.3.2 比較運算子

# %%
120 > 32.5
# Out:
# True

# %%
7 >= 12
# Out:
# False

# %%
'Cats' < 'cat'
# Out:
# True

# %%
print(ord('C'), ord('c'))
# Out:
# 67 99

# %%
12==12.
# Out:
# True

# %%
'Python' != 'Java'
# Out:
# True

# %% [markdown]
# #### 2.3.2 邏輯運算子

# %%
5<3 and 6<10
# Out:
# False

# %%
4<7 and 8<7 and 3>0
# Out:
# False

# %%
4<5 or 9>12
# Out:
# True

# %%
'a'=='a' or 7==2 and 8<5
# Out:
# True

# %%
('a'=='a' or 7==2) and 8<5
# Out:
# False

# %%
not 2**3 < 10
# Out:
# False

# %%
bool('cat')
# Out:
# True

# %%
not 'cat'
# Out:
# False

# %%
bool()
# Out:
# False

# %%
bool(3.14)
# Out:
# True

# %%
bool('')
# Out:
# False

# %%
bool(0.000)
# Out:
# False

# %%
bool(0.000000001)
# Out:
# True

# %%
5!=7 and 6<0 and 8==8
# Out:
# False

# %%
'cat' and 'pig'
# Out:
# 'pig'

# %%
'cat' and 'pig' and 'dog'
# Out:
# 'dog'

# %%
'cat' or 'pig'
# Out:
# 'cat'

# %%
'' or 'pig'
# Out:
# 'pig'

# %% [markdown]
# #### 2.3.4 位元運算子

# %%
x = 9; y = 14

# %%
bin(x)
# Out:
# '0b1001'

# %%
bin(y)
# Out:
# '0b1110'

# %%
x and y
# Out:
# 14

# %%
x & y
# Out:
# 8

# %%
x | y
# Out:
# 15

# %%
x ^ y
# Out:
# 7

# %%
~x
# Out:
# -10

# %%
x << 2
# Out:
# 36

# %%
x >> 2
# Out:
# 2

# %% [markdown]
# ### 2.4 變數的設值與運算的優先順序

# %% [markdown]
# #### 2.4.1 變數的設值

# %%
x = 12

# %%
x += 1

# %%
x
# Out:
# 13

# %%
x *= 2

# %%
x
# Out:
# 26

# %% [markdown]
# #### 2.4.2 運算的優先順序

# %%
6 + 2**3 * 4
# Out:
# 38

# %%
'piggy' and not 'good'
# Out:
# False

# %%
x = 2 + 1

# %%
x += x**2 + 4; x
# Out:
# 16

# %% [markdown]
# ### 2.5 型別轉換

# %%
5 + 4.2
# Out:
# 9.2

# %%
19 + True
# Out:
# 20

# %% [markdown]
# #### 2.5.2 顯式轉換

# %%
int(4.78)
# Out:
# 4

# %%
# '2020' + 4

# %%
int('2020') + 4
# Out:
# 2024

# %%
float(100)
# Out:
# 100.0

# %%
float('6.28')
# Out:
# 6.28

# %%
eval('6.28')
# Out:
# 6.28

# %%
#float('6.28+12.4')

# %%
eval('6.28+12.4')
# Out:
# 18.68

# %%
complex(7,8)
# Out:
# (7+8j)

# %%
complex('6+4j')
# Out:
# (6+4j)

# %%
poly='x**3+2*x**2+5*x+4'

# %%
x=1; eval(poly)
# Out:
# 12

# %%
x=2; eval(poly)
# Out:
# 30

# %% [markdown]
# ### 2.6 不同進位數的轉換

# %%
int('0b11000011',2)
# Out:
# 195

# %%
int('11000011',2)
# Out:
# 195

# %%
bin(3**64)
# Out:
# '0b101011010101101101010010101111100011110111100100110010001001111000110001111001011111101011110100000001'

# %%
int('0xef10', 16)
# Out:
# 61200

# %%
hex(61200)
# Out:
# '0xef10'

# %%
oct(256)
# Out:
# '0o400'

# %% [markdown]
# ### 2.7 輸出與輸入函數

# %% [markdown]
# #### 2.7.1 Python的輸出函數- print()

# %%
print('Hello Python')
# Out:
# Hello Python

# %%
print(10, 20, 30)
# Out:
# 10 20 30

# %%
print(10, 20, 30, sep='+')
# Out:
# 10+20+30

# %%
print(10,20,30,sep='*',end='@')
# Out:
# 10*20*30@

# %%
print(12); print(14)
# Out:
# 12
# 14

# %%
print(12,end='#'); print(14)
# Out:
# 12#14

# %%
print('Hi',end=''); print('Python')
# Out:
# HiPython

# %%
#print('Hello 'Python'')

# %%
print('Hello \'Python\'')
# Out:
# Hello 'Python'

# %%
print('A back slash \\ symbol\a ')
# Out:
# A back slash \ symbol

# %%
print('\"A string\"')
# Out:
# "A string"

# %%
print('"A string"')
# Out:
# "A string"

# %%
print("It's a sunny day")
# Out:
# It's a sunny day

# %% [markdown]
# #### 2.7.2 輸出字串的格式化

# %%
i,f,s = 12,6.282,'Python'

# %%
print('i=%d' % i)
# Out:
# i=12

# %%
print('i=%3d' % i)
# Out:
# i= 12

# %%
print('i=%d, s=%s' % (i,s))
# Out:
# i=12, s=Python

# %%
print('i=%05d, s=%7s' % (i,s))
# Out:
# i=00012, s= Python

# %%
print('f=%5.2f, i=%+4d' % (f,i))
# Out:
# f= 6.28, i= +12

# %%
i,f,s = 12000,3.14,'Python'

# %%
print(f'i={i}, f={f}, s={s}')
# Out:
# i=12000, f=3.14, s=Python

# %%
print(f'int={i:+,}, float={f:6.2f}')
# Out:
# int=+12,000, float=  3.14

# %%
print(f'int={i:b}, str={s:>8}')
# Out:
# int=10111011100000, str=  Python

# %%
print(f'int={i:#x}, str={s:>08}')
# Out:
# int=0x2ee0, str=00Python

# %%
print(f'float={f*2:5.2f}')
# Out:
# float= 6.28

# %%
print(f'Addition:{{4+5:^3d}}')
# Out:
# Addition:{4+5:^3d}

# %%
print(f'Addition:{{{4+5:^3d}}}')
# Out:
# Addition:{ 9 }

# %%
s1='Hello'; s2='World'

# %%
print(f'字串相加：\'{s1}\'+\'{s2}\'')
# Out:
# 字串相加：'Hello'+'World'

# %% [markdown]
# #### 2.7.3 Python的輸入函數- input()

# %%
num=input('Input a number: ')
# Out:
# Input a number: 12

# %%
num
# Out:
# '12'

# %%
expr=input('input an expression: ')
# Out:
# input an expression: 2+7

# %%
expr
# Out:
# '2+7'

# %%
eval(expr)
# Out:
# 9
