# %% [markdown]
# <font color=#1E8449>☘ </font> 注意事項
# 1. 如果您使用 Colab，在您熟悉 Colab 的操作環境之後，建議把介面改成英文版，以便讓程式碼有最好的顯示效果
#  * 選擇 Colab 功能表裡的 <font color=#E59866>說明</font> - <font color=#E59866>查看英文版本</font> 即可將介面改成英文版
#  * 要改回中文版，請關掉目前開啟的 Colab 網頁，再重新開啟您執行的 Colab 檔案即可（Colab 預設為中文版）
# 2. 建議選擇暗色背景，長時間撰寫程式時眼睛會比較舒服
#  * 在 Colab 裡選擇 <font color=#E59866>Tools（工具）</font> - <font color=#E59866> Settings （設定）</font> - <font color=#E59866> Site（網站）</font> - <font color=#E59866> Theme （主題）</font> - <font color=#E59866> Dark </font>
#  * 在 Jupyter lab 中選擇 <font color=#E59866> Settings </font> - <font color=#E59866> JupyterLab theme </font> - <font color=#E59866> JupyerterLab Dark </font>

# %% [markdown]
# ## Chap 03 數值與字串的處理

# %% [markdown]
# ### 3.1 數值運算

# %% [markdown]
# #### 3.1.1 內建數學函數

# %%
abs(-4.8)
# Out:
# 4.8

# %%
round(3.14159)
# Out:
# 3

# %%
round(3.14159,3)
# Out:
# 3.142

# %%
pow(2,100)
# Out:
# 1267650600228229401496703205376

# %%
pow(2,0.5)
# Out:
# 1.4142135623730951

# %%
max(9, 12, 87.2)
# Out:
# 87.2

# %%
min(8, -32, 62.9, 20)
# Out:
# -32

# %% [markdown]
# #### 3.1.2 math 模組裡的基本數學函數

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.inf-100
# Out:
# inf

# %%
math.inf*0
# Out:
# nan

# %%
math.fabs(-90)
# Out:
# 90.0

# %%
math.factorial(5)
# Out:
# 120

# %%
math.factorial(50)
# Out:
# 30414093201713378043612608166064768844377641568960512000000000000

# %%
math.ceil(9.1)
# Out:
# 10

# %%
math.floor(28.7)
# Out:
# 28

# %%
math.fmod(23,4)
# Out:
# 3.0

# %%
math.gcd(36,64)
# Out:
# 4

# %%
math.isfinite(90)
# Out:
# True

# %%
math.isinf(math.inf/100)
# Out:
# True

# %%
math.isnan(math.inf/math.inf)
# Out:
# True

# %% [markdown]
# #### 3.1.3 math 模組裡的指數、對數與三角函數

# %%
math.exp(1)
# Out:
# 2.718281828459045

# %%
math.log(math.exp(20.3))
# Out:
# 20.3

# %%
math.log(1000,10)
# Out:
# 2.9999999999999996

# %%
math.log10(1000)
# Out:
# 3.0

# %%
math.pow(3,50)
# Out:
# 7.178979876918526e+23

# %%
pow(3,50)
# Out:
# 717897987691852588770249

# %%
3**50
# Out:
# 717897987691852588770249

# %%
math.sqrt(3)
# Out:
# 1.7320508075688772

# %%
math.sin(math.pi/6)
# Out:
# 0.49999999999999994

# %%
math.degrees(math.asin(0.5))
# Out:
# 30.000000000000004

# %%
math.degrees(math.atan(1))
# Out:
# 45.0

# %%
math.degrees(math.atan2(-1,-1))
# Out:
# -135.0

# %%
math.radians(180)
# Out:
# 3.141592653589793

# %%
math.sinh(1)
# Out:
# 1.1752011936438014

# %% [markdown]
# ### 3.2 random 模組裡的函數

# %%
import random

# %%
random.random()
# Out:
# 0.297844768239409

# %%
random.randint(0,10)
# Out:
# 7

# %%
random.uniform(-1,1)
# Out:
# -0.48896651814782355

# %%
random.choice('Python')
# Out:
# 'o'

# %%
random.choice([1,7,3,2,9])
# Out:
# 9

# %%
random.randrange(1,6)
# Out:
# 5

# %%
random.randrange(-3,3,2)
# Out:
# -1

# %%
random.sample('Hello Python',3)
# Out:
# ['l', 'P', 'h']

# %%
lst=[9,2,3,1,0]

# %%
random.shuffle(lst)

# %%
lst
# Out:
# [3, 0, 9, 1, 2]

# %%
random.seed(999)

# %%
print(random.random())
print(random.random())
print(random.random())
# Out:
# 0.7813468849570298
# 0.0800656147037001
# 0.8724924964292878

# %%
random.seed(999)

# %%
print(random.random())
print(random.random())
print(random.random())
# Out:
# 0.7813468849570298
# 0.0800656147037001
# 0.8724924964292878

# %% [markdown]
# ### 3.3 字串的處理函數

# %% [markdown]
# #### 3.3.1 認識 Python 字元的編碼

# %%
print(ord('a'), ord('3'), ord('好'))
# Out:
# 97 51 22909

# %%
print(ord('Z'), ord('#'))
# Out:
# 90 35

# %%
print(hex(90),hex(35))
# Out:
# 0x5a 0x23

# %%
chr(0x23)
# Out:
# '#'

# %%
chr(22909)
# Out:
# '好'

# %%
print('A slash character: \x2f')
# Out:
# A slash character: /

# %%
print('A slash character: \057')
# Out:
# A slash character: /

# %%
print('An uncode character: \u597d')
# Out:
# An uncode character: 好

# %% [markdown]
# #### 3.3.2 內建的字串處理函數

# %%
str1='歡迎Welcome'

# %%
min(str1)
# Out:
# 'W'

# %%
max(str1)
# Out:
# '迎'

# %%
for c in str1:
    print(ord(c))
# Out:
# 27489
# 36814
# 87
# 101
# 108
# 99
# 111
# 109
# 101

# %%
chr(99)
# Out:
# 'c'

# %%
ord('W')
# Out:
# 87

# %%
len(str1)
# Out:
# 9

# %%
str(3.14)
# Out:
# '3.14'

# %% [markdown]
# #### 3.3.3 處理字串的運算子

# %%
'520'*3
# Out:
# '520520520'

# %%
'Have '+'a '+'nice '+'day'
# Out:
# 'Have a nice day'

# %%
'W'<'e'
# Out:
# True

# %%
'歡'>='迎'
# Out:
# False

# %%
'holiday'=='birthday'
# Out:
# False

# %%
'mat' in 'formation'
# Out:
# True

# %%
'tion' not in 'formation'
# Out:
# False

# %%
'from' not in 'formation'
# Out:
# True

# %%
s1='Wonderful tonight'

# %%
s1[0:6]
# Out:
# 'Wonder'

# %%
s1[:6]
# Out:
# 'Wonder'

# %%
s1[3:6]
# Out:
# 'der'

# %%
s1[10:]
# Out:
# 'tonight'

# %%
s1[-1]
# Out:
# 't'

# %%
s1[10:-5]
# Out:
# 'to'

# %%
s1[-5:]
# Out:
# 'night'

# %%
s2='Python程式設計'

# %%
s2[-4:]
# Out:
# '程式設計'

# %%
s2[:6]
# Out:
# 'Python'

# %% [markdown]
# ### 3.4 字串類別提供的函數

# %%
type(5)
# Out:
# int

# %%
type('nice')
# Out:
# str

# %%
'nice'.capitalize()
# Out:
# 'Nice'

# %%
str.capitalize('nice')
# Out:
# 'Nice'

# %% [markdown]
# #### 3.4.1 字串大小寫的轉換函數

# %% [markdown]
# <font color=#DB9B1A>- 字串大小寫的轉換函數 - </font>
#
# * upper()、lower()：將字串全部轉換成大寫/小寫
# * swapcase()：將字串的大小寫互換
# * capitalize()：將字串的第一個字母大寫
# * title()：將字串裡，每一個單字的第一個字母轉成大寫

# %%
s1='machine LEARNing'

# %%
s1.upper()
# Out:
# 'MACHINE LEARNING'

# %%
s1
# Out:
# 'machine LEARNing'

# %%
str.upper(s1)
# Out:
# 'MACHINE LEARNING'

# %%
s1
# Out:
# 'machine LEARNing'

# %%
s1.lower()
# Out:
# 'machine learning'

# %%
s1.swapcase()
# Out:
# 'MACHINE learnING'

# %%
s1.title()
# Out:
# 'Machine Learning'

# %%
s1.capitalize()
# Out:
# 'Machine learning'

# %%
str='holiday'

# %%
# str.upper('aaa')

# %%
del str

# %%
str.upper('aaa')
# Out:
# 'AAA'

# %% [markdown]
# #### 3.4.2 字串檢測函數

# %%
'Python'.isupper()
# Out:
# False

# %%
str.islower('python')
# Out:
# True

# %%
'Data Science'.istitle()
# Out:
# True

# %%
'hello 123'.isalpha()
# Out:
# False

# %%
'123.456'.isdigit()
# Out:
# False

# %%
'520'.isdigit()
# Out:
# True

# %%
'123.456'.isalnum()
# Out:
# False

# %%
'123abc'.isalnum()
# Out:
# True

# %%
'str'.isidentifier()
# Out:
# True

# %%
'7up'.isidentifier()
# Out:
# False

# %%
'my cats'.isidentifier()
# Out:
# False

# %%
'd  '.isspace()
# Out:
# False

# %%
'flag'.startswith('f')
# Out:
# True

# %%
'flag corporation'.endswith('n')
# Out:
# True

# %% [markdown]
# #### 3.4.3 字串搜尋函數

# %%
s1='learing by doing'

# %%
s1.count('n')
# Out:
# 2

# %%
s1.count('ing')
# Out:
# 2

# %%
s1.find('ing')
# Out:
# 4

# %%
s1.rfind('ing')
# Out:
# 13

# %%
s1.find('w')
# Out:
# -1

# %% [markdown]
# #### 3.4.4 字串編修函數

# %%
s1='data science'

# %%
s1.replace('science','scientist')
# Out:
# 'data scientist'

# %%
s1.title().replace(' ','')
# Out:
# 'DataScience'

# %%
'  python  '.lstrip()
# Out:
# 'python  '

# %%
'  python  '.strip()
# Out:
# 'python'

# %%
'data science'.strip()
# Out:
# 'data science'

# %%
'www.buffalo.edu'.lstrip('@wi.')
# Out:
# 'buffalo.edu'

# %%
'www.buffalo.edu'.strip('.deuw')
# Out:
# 'buffalo'

# %%
'www.buffalo.edu'.rstrip('.deuw')
# Out:
# 'www.buffalo'

# %%
'Jeanne'.ljust(8)
# Out:
# 'Jeanne  '

# %%
'Tom'.rjust(8)
# Out:
# '     Tom'

# %%
'Teresa'.center(8)
# Out:
# ' Teresa '

# %%
'2025'.zfill(8)
# Out:
# '00002025'

# %%
'+'.join(['100','200'])
# Out:
# '100+200'

# %%
' '.join(['Wonderful','tonight'])
# Out:
# 'Wonderful tonight'

# %%
''.join(['a','p','p','l','e'])
# Out:
# 'apple'

# %% [markdown]
# #### 3.4.5 格式化函數 format()

# %%
'{} {}'.format("Hello", "Python")
# Out:
# 'Hello Python'

# %%
'{1} {0}'.format("Hello", "Python")
# Out:
# 'Python Hello'

# %%
'{0}! {0}! {1}'.format("Hello", "Python")
# Out:
# 'Hello! Hello! Python'

# %%
'{0}+{1}={2}'.format(5,3,5+3)
# Out:
# '5+3=8'

# %%
'姓名:{n}, 信箱：{eM}'.format(n='Tom',eM='tom@buf.com')   # 給予參數名稱
# Out:
# '姓名:Tom, 信箱：tom@buf.com'

# %%
data=['Tom','tom@buf.com']

# %%
data[0]
# Out:
# 'Tom'

# %%
data[1]
# Out:
# 'tom@buf.com'

# %%
'姓名:{n}, 信箱：{eM}'.format(n=data[0],eM=data[1])
# Out:
# '姓名:Tom, 信箱：tom@buf.com'

# %%
'姓名:{0[0]}, 信箱：{0[1]}'.format(data)
# Out:
# '姓名:Tom, 信箱：tom@buf.com'

# %%
psnr=48.1376
print('qL={0:6.2f}dB'.format(psnr))
# Out:
# qL= 48.14dB

# %%
pL=163762

# %%
print('qL={0:6.2f}dB, pL={1:7,d}bpp'.format(psnr,pL))
# Out:
# qL= 48.14dB, pL=163,762bpp

# %%
'Drink: {{{0}}}'.format('coffee')
# Out:
# 'Drink: {coffee}'

# %%
s1='Hello'; s2='Kitty'

# %%
"Say '{0}' to {1}".format(s1,s2)
# Out:
# "Say 'Hello' to Kitty"
